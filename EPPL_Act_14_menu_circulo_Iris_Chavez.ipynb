# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280032-boop/EPPL-Act-14-menu-circulo-funciones-area-perimetro-y-volumen-/blob/main/EPPL_Act_14_menu_circulo_Iris_Chavez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Iris Chaves NL = 11 Fecha 13/Abril/2026
# ####📄 Redaccion: Geometria Computacional para principiantes En el estudio de la programacion y las matematicas aplicadas, es fundamental aprender a traducir conceptos geometricos en algoritmos claros y funcionales. Este proyecto se centra en tres calculos basicos pero esenciales: el area de un circulo, su perimetro (tambien conocido como circunferencia) y el volumen de una esfera. las formulas matematicas que sustentan estos calculos son las siguientes:
#  1. 🔹 Area del ciculo: A = pi . r2
#  2. 🔹 Perimetro del circulo: P = 2 . pi , r
#  3. 🔹 Volumen de la esfera: V = (4/3) . pi . r3
#
# ![formulas](https://raw.githubusercontent.com/a25308051280032-boop/mis-imagenes-de-EPPL-Unidad-2/refs/heads/main/el%20circulo.PNG)

# %%
import math

def areacirculo():
    print("\n--- 🟢 Calculando Área ---")
    radio = float(input("Introduce el valor del radio: "))
    area = math.pi * (radio ** 2)
    print(f"✨ El área del círculo es: {area:.2f} u²")

# Función para calcular el perímetro del círculo
def perimetrocirculo():
    print("\n--- 🔵 Calculando Perímetro ---")
    radio = float(input("Introduce el valor del radio: "))
    perimetro = 2 * math.pi * radio
    print(f"✨ El perímetro es: {perimetro:.2f} u")

# Función para calcular el volumen de la esfera
def volumenesfera():
    print("\n--- 🟣 Calculando Volumen ---")
    radio = float(input("Introduce el valor del radio: "))
    volumen = (4/3) * math.pi * (radio ** 3)
    print(f"✨ El volumen de la esfera es: {volumen:.2f} u³")

# Función principal del menú
def menu():
    continuar = True

    while continuar:
        print("\n" + "="*30)
        print("    🍎 ASISTENTE GEOMÉTRICO 🍎")
        print("="*30)
        print("1️⃣ Calcular área círculo")
        print("2️⃣ Calcular perímetro círculo")
        print("3️⃣ Calcular volumen esfera")
        print("4️⃣ Salir ❌")

        opcion = input("\nSelecciona una opción (1-4): ")

        if opcion == "1":
            areacirculo()
        elif opcion == "2":
            perimetrocirculo()
        elif opcion == "3":
            volumenesfera()
        elif opcion == "4":
            print("\n👋 ¡Gracias por usar el programa! Hasta pronto. ✨")
            continuar = False
        else:
            print("\n⚠️ Opción no válida, intenta de nuevo.")

# Llamada inicial al programa
menu()
print("Programa realizado por Iris Chavez NL = 11")
# Out:
# ...
#     🍎 ASISTENTE GEOMÉTRICO 🍎
# ...
# 1️⃣ Calcular área círculo
# 2️⃣ Calcular perímetro círculo
# 3️⃣ Calcular volumen esfera
# 4️⃣ Salir ❌
#
# Selecciona una opción (1-4): 1
#
# --- 🟢 Calculando Área ---
# Introduce el valor del radio: 5
# ✨ El área del círculo es: 78.54 u²
#
# ...
#     🍎 ASISTENTE GEOMÉTRICO 🍎
# ...
# 1️⃣ Calcular área círculo
# 2️⃣ Calcular perímetro círculo
# 3️⃣ Calcular volumen esfera
# 4️⃣ Salir ❌
#
# Selecciona una opción (1-4): 2
#
# --- 🔵 Calculando Perímetro ---
# Introduce el valor del radio: 6
# ✨ El perímetro es: 37.70 u
#
# ...
#     🍎 ASISTENTE GEOMÉTRICO 🍎
# ...
# 1️⃣ Calcular área círculo
# 2️⃣ Calcular perímetro círculo
# 3️⃣ Calcular volumen esfera
# 4️⃣ Salir ❌
#
# Selecciona una opción (1-4): 3
#
# --- 🟣 Calculando Volumen ---
# Introduce el valor del radio: 7
# ✨ El volumen de la esfera es: 1436.76 u³
#
# ...
#     🍎 ASISTENTE GEOMÉTRICO 🍎
# ...
# 1️⃣ Calcular área círculo
# 2️⃣ Calcular perímetro círculo
# 3️⃣ Calcular volumen esfera
# 4️⃣ Salir ❌
#
# Selecciona una opción (1-4): 4
# ...

# %% [markdown]
# ![](https://private-user-images.githubusercontent.com/260754563/588373204-65971334-a3f1-4b0f-bb0d-734041206487.png?jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmF3LmdpdGh1YnVzZXJjb250ZW50LmNvbSIsImtleSI6ImtleTUiLCJleHAiOjE3NzgwODAyMTksIm5iZiI6MTc3ODA3OTkxOSwicGF0aCI6Ii8yNjA3NTQ1NjMvNTg4MzczMjA0LTY1OTcxMzM0LWEzZjEtNGIwZi1iYjBkLTczNDA0MTIwNjQ4Ny5wbmc_....OuFESKmZmXAaC8Wm528xLgETkHB3HEndrMTvEirJw0g)
